# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

plt.rc('text', usetex=True)

# %%
fig=plt.figure()
dom = np.arange(5000)
plt.plot(dom, dom, label=r"h_{+}")
plt.title("Gravitational Waveform")
plt.legend()
ticks = plt.xticks()[0][1:-1];
newlabs = [int(i)/100 for i in (ticks*100/(60*60*24*365))];
plt.xticks(ticks, newlabs);
# Out:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f8a86a75560> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /mnt/Data_Volume/Computer_Programs/Anaconda/envs/few_env/lib/python3.7/site-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex, cwd)
#     234                 command, cwd=cwd if cwd is not None else self.texcache,
# --> 235                 stderr=subprocess.STDOUT)
#     236         except FileNotFoundError as exc:
#
# /mnt/Data_Volume/Computer_Programs/Anaconda/envs/few_env/lib/python3.7/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     410     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 411                **kwargs).stdout
#     412
#
# ...

# %%
fig=plt.figure()
a = plt.plot([1,2,3,4,5]);
b = plt.plot([4,5,6,7,8])
c=plt.show(a,b)

# %%
with open("testfile", "wb") as file:
    pickle.dump(fig,file)

# %%
with open("testfile", "rb") as file:
    figure = pickle.load(file)

# %%
figure
