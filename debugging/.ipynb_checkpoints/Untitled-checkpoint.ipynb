# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import glob
import numpy as np

# %%
foldpath = "/home/shaunf/tmp/Output/"
filenames = glob.glob(foldpath+"*")
dat = []
for file in filenames:
    with open(file, "r") as fileobj:
        dat.append(json.load(fileobj))
data = pd.DataFrame(dat)

# %%
plt.scatter(data["PROCAMASS"], data["faithfulness"])

# %%
plt.scatter(data["PROCAMASS"], np.abs(data["DeltaNOrbits"]))
